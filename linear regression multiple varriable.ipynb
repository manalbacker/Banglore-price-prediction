# %%
import math
median_bedroom =math.floor(df.no_of_bedrooms.median())
median_bedroom
# Out:
# 3

# %%
df.no_of_bedrooms = df.no_of_bedrooms.fillna(median_bedroom)
df
# Out:
#    area   price  no_of_bedrooms  age
# 0  1000  200000             2.0   10
# 1  1500  250000             3.0    5
# 2  2000  300000             3.0   15
# 3  2500  350000             4.0   20
# 4  3000  400000             4.0   30

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area','no_of_bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([ 1.00000000e+02, -2.31637848e-11, -4.63290875e-12])

# %%
reg.intercept_
# Out:
# 99999.99999999997

# %%
reg.predict([[3000,4,30]])
# Out:
# C:\Users\munab\anaconda3\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([400000.])

# %%
dt=pd.read_csv(r"C:\Users\munab\code basics\hiring.csv")
dt
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
dt['experience'] = dt['experience'].replace('zerp', 'zero')
dt
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
# !pip install word2number
# Out:
# ...
#   Using cached word2number-1.1-py3-none-any.whl
# ...

# %%
from word2number import w2n

# %%
dt.experience = dt.experience.apply(w2n.word_to_num)
dt
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
import math

# %%
median_testscore= math.floor(dt['test_score(out of 10)'].mean())
median_testscore
# Out:
# 7

# %%
dt['test_score(out of 10)'] = dt['test_score(out of 10)'].fillna(median_testscore)
dt
dt.drop('test_score(out of 10)_score(out of 10)',axis=1)
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()
reg.fit(dt[['experience','test_score(out of 10)','interview_score(out of 10)']],dt['salary($)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])
# Out:
# C:\Users\munab\anaconda3\anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([53713.86677124])
